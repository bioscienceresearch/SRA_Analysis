# %% [markdown]
# ## Use BLAST2 to check for sequences

# %%
import os
import time
import pandas as pd
import numpy as np
import pathlib
from io import StringIO
from Bio import SeqIO
from Bio.Cluster import distancematrix
from Bio.Blast.Applications import NcbiblastnCommandline
from Bio.Blast import NCBIWWW
from Bio.Blast import NCBIXML
import subprocess
from recan.simgen import Simgen
from matplotlib import pyplot as plt
import seaborn as sns
from os import listdir
from os.path import isfile, join

# %%
pd.options.display.max_seq_items = 2000

# %% [markdown]
# ```
# makeblastdb -in SRR5722761_final.contigs.fa -dbtype nucl -parse_seqids -out /mnt/1TB_ssd/Data/BLAST/asm_db/SRR5722761_megahit_default
# ```
#
#
# ```
# export BLASTDB=/mnt/1TB_ssd/Data/BLAST/asm_db
# ```

# %%
PROJECT_CODE='PRJNA396502'

BASE_PATH=f'/mnt/1TB_0/Data/Assembly/'

# %%
SRA_LIST=['SRR5885860']

# %% [markdown]
# ### BSL3/4 organisms and vector search and Bat CoV search

# %%
ORGANISM_CSVS=['/mnt/1TB_0/Data/fasta/organisms_all.csv', '/mnt/1TB_0/Data/fasta/cov_common_name.csv']
CSV_PATHS=['/mnt/1TB_0/Data/fasta/complete_nucleotide/','/mnt/1TB_0/Data/fasta/common_name_fasta/']

# %%
def make_db(asm_path, sra_code):
    cmd = f"makeblastdb -in {asm_path+sra_code}_final.contigs.fa -dbtype nucl -parse_seqids -out /mnt/1TB_ssd/Data/BLAST/asm_db/{sra_code}_megahit_default"
    subprocess.check_call(cmd, shell=True)

# %%
cmd = "export BLASTDB=/mnt/1TB_ssd/Data/BLAST/asm_db"
subprocess.check_call(cmd, shell=True)
# Out:
# 0

# %%
def check_path(sequences, fasta_path):
    for fname in sequences:
        if not os.path.isfile(fasta_path+fname):
            print(f'File non existant: {fasta_path}{fname}')

# %%
def get_data(df):
    sequences=df['File_Name']
    accessions=df['Accession']
    assert len(sequences)==len(accessions)
    return sequences, accessions

# %%
def run_blast2(sequences, accessions, sra_code, fasta_path, out_file_path):
    for g, asc in zip(sequences, accessions):
        out_file=f'{sra_code}_{asc}_BLAST2.txt'
        db=f'{sra_code}_megahit_default'
        cmd = f"blastn -query {fasta_path+g} -db {db} -num_threads 6 -out {out_file_path+out_file} -evalue 0.001 -max_target_seqs 100 -perc_identity 90 -max_hsps 10"
        subprocess.check_call(cmd, shell=True)

# %%
def cleanup(sequences, accessions, sra_code, out_file_path):
    del_list=[]
    for g, asc in zip(sequences, accessions):
        out_file=f'{sra_code}_{asc}_BLAST2.txt'
        with open(out_file_path+out_file) as myfile:
            if '***** No hits found *****' in myfile.read():
                del_list.append(out_file)
    for f in del_list:
        if os.path.exists(out_file_path+f):
            os.remove(out_file_path+f)
        else:
            print(f"{f} does not exist")

# %%
def blast_workflow(sequences, accessions,csv_path, search_name, rebuild_db):
    match_dict={}
    for sra_code in SRA_LIST:
        start_time=time.time()
        print(f'Running blast2 on {sra_code}')
        matches=[]
        data_path=f'{BASE_PATH}{PROJECT_CODE}/{sra_code}/'
        asm_path=data_path+'megahit_default/'
        b_path=data_path+f'megahit_asm_BLAST2/'
        pathlib.Path(b_path).mkdir(exist_ok=True)
        out_file_path=data_path+f'megahit_asm_BLAST2/{search_name}/'
        pathlib.Path(out_file_path).mkdir(exist_ok=True)
        if rebuild_db:
            make_db(asm_path, sra_code)
        elif not os.path.isfile(f'/mnt/1TB_ssd/Data/BLAST/asm_db/{sra_code}_megahit_default.ndb'):
            make_db(asm_path, sra_code)
        run_blast2(sequences, accessions, sra_code, csv_path, out_file_path)
        cleanup(sequences, accessions, sra_code, out_file_path)
        matchfiles = [f for f in listdir(out_file_path) if isfile(join(out_file_path, f))]
        for f in matchfiles:
            asc=f.split('_',1)[1]
            asc=asc.split('_BLAST2.txt')[0]
            try:
                idx = accessions.tolist().index(asc.strip())
                match=sequences[idx]
                matches.append(match)
            except ValueError as e:
                print(f'accessions:{str(accessions.tolist())}')
                print(f'asc: {asc}, file: {f} error: {e}')
                raise ValueError
        match_dict[sra_code]=matches
        print(f'Elapsed: {time.time()-start_time}')
    return match_dict

# %%
def main_worflow(organism_csv, csv_path, search_name, rebuild_db):
    result_list=[]
    df=pd.read_csv(organism_csv)
    sequences, accessions=get_data(df)
    match_dict=blast_workflow(sequences, accessions,csv_path, search_name, rebuild_db)
    result_list.append(match_dict)
    return result_list

# %% [markdown]
# ## BSL organism hits

# %%
bsl_result_list=main_worflow(ORGANISM_CSVS[0],CSV_PATHS[0], search_name='bsl', rebuild_db=True)
# Out:
# Running blast2 on SRR5885860
# Elapsed: 326.1996157169342

# %%
bsl_result_list
# Out:
# [{'SRR5885860': ['NC_000007_14_CFTR_gene.fa',
#    'JN950623_1_Mus_musculus_targeted_non-conditional_lacZ-tagged_mutant_allele_Herc1_tm1e_EUCOMM_Wtsi_transgenic.fa',
#    'KJ473820_1_BtPa-BetaCoV_GD2013_complete_genome.fa',
#    'MK787297_1_cloning_vector_pR6K-KCA.fa',
#    'MK280359_1_Homo_sapiens_lncAB370_3_lncRNA_gene_complete_sequence.fa',
#    'MK279923_1_Homo_sapiens_lncAB599_3_lncRNA_gene_complete_sequence.fa',
#    'MK280367_1_Homo_sapiens_lncAB371_6_lncRNA_gene_complete_sequence.fa',
#    'MN996867_1_Cloning_vector_pcDNA3_1_complete_sequence.fa',
#    'NC_006549_1_Singapore_grouper_iridovirus_complete_genome.fa',
#    'MN611520_1_Pipistrellus_abramus_bat_coronavirus_HKU5-related_isolate_BY140568_complete_genome.fa',
#    'NC_000004_12_ABCG2_gene.fa',
#    'NC_000005_10_TERT_gene.fa',
#    'EU410304_1_Synthetic_Vaccinia_virus_clone_GLV-1h68_complete_genome.fa',
#    'NC_009020_1_HKU5_complete_genome.fa',
#    'MF164268_1_Homo_sapiens_clone_BAC_JH12_genomic_sequence.fa']}]

# %% [markdown]
# ### BSL list of organisms we are shearching for

# %%
pd.options.display.max_rows = 2000
df=pd.read_csv(ORGANISM_CSVS[0])
df
# Out:
#                                                  Name  \
# 0                   Bacteriophage_S13_complete_genome
# 1   Human_endogenous_retrovirus_H_HERV-H_env62_pro...
# 2   Porcine_hemagglutinating_encephalomyelitis_vir...
# 3         Bat_SARS_coronavirus HKU3-1_complete_genome
# 4                      Coliphage_ID45_complete_genome
# 5                      Coliphage_WA11_complete_genome
# 6         bat_SARS_coronavirus_HKU3-2_complete_genome
# 7         bat_SARS_coronavirus_HKU3-3_complete_genome
# 8   Synthetic_Vaccinia_virus_clone_GLV-1h68_comple...
# 9            Cote_d-Ivoire_ebolavirus_complete_genome
# 10  XMRV-like_mouse_endogenous_retrovirus_mERV-XL_...
# 11   Bat_SARS-like_coronavirus_Rs3367_complete_genome
# 12     Bat_SARS-like_coronavirus_WIV1_complete_genome
# 13  Human_coronavirus_HKU1_strain_HKU1-human-USA-H...
# 14          Enterobacteria_phage_MED1_complete_genome
# 15  Human_adenovirus_12_isolate_GyK010_complete_ge...
# 16              Mengo_virus_isolate_M_complete_genome
# 17  Woodchuck_hepatitis_virus_WHV_complete_genome_...
# 18  Bat_SARS-like_coronavirus_isolate_bat-SL-CoVZC...
# 19  Porcine_deltacoronavirus_isolate_CH_JXJGS01_20...
# 20  Swine_acute_diarrhea_syndrome_coronavirus_stra...
# 21  Rabies_lyssavirus_isolate_19RS359_complete_genome
# 22                             RaTG13_complete_genome
# 23          Cloning_vector_pcDNA3_1_complete_sequence
# 24  Friend_murine_leukemia_virus_FB29_complete_genome
# 25                 Japanese_encephalitis_virus_genome
# 26  Avian_infectious_bronchitis_virus_complete_genome
# 27                 Human_adenovirus_A_complete_genome
# 28                     Dengue_virus_2_complete_genome
# 29                     Dengue_virus_1_complete_genome
# 30       Moloney_murine_sarcoma_virus_complete_genome
# 31      Simian_immunodeficiency_virus_complete_genome
# 32  Marburg_marburgvirus_isolate_Marburg_virus-H.s...
# 33  African_swine_fever_virus_strain_BA71V_complet...
# 34                    Simian_virus_40_complete_genome
# 35                       Hendra_virus_complete_genome
# 36             canine_distemper_virus_complete_genome
# 37  Feline_infectious_peritonitis_virus_complete_g...
# 38             Human_coronavirus_229E_complete_genome
# 39                        Nipah_virus_complete_genome
# 40    Porcine_epidemic_diarrhea_virus_complete_genome
# 41                       Cowpox_virus_complete_genome
# 42               Goatpox_virus_Pellor_complete_genome
# 43       Hepatitis_C_virus_genotype_1_complete_genome
# 44                  Chikungunya_virus_complete_genome
# 45              SARS_coronavirus_Tor2_complete_genome
# 46  Crimean-Congo_hemorrhagic_fever_virus_segment_...
# 47  Crimean-Congo_hemorrhagic_fever_virus_segment_...
# 48  Crimean-Congo_hemorrhagic_fever_virus_segment_...
# 49  Human_coronavirus_OC43_strain_ATCC_VR-759_comp...
# 50  Human_herpesvirus_5_strain_Merlin_complete_genome
# 51       Singapore_grouper_iridovirus_complete_genome
# 52                               HKU4_complete_genome
# 53                               HKU5_complete_genome
# 54                         Zika_virus_complete_genome
# 55  Middle_East_respiratory_syndrome-related_coron...
# 56  Hubei_picorna-like_virus_45_strain_spider13352...
# 57  Vesicular_stomatitis_Indiana_virus_strain_98CO...
# 58  UNVERIFIED_African_swine_fever_virus_isolate_O...
# 59              SARS_CoV_2_Wuahn-Hu-1_complete_genome
# 60  Murine_hepatitis_virus_strain_A59_complete_genome
# 61  Avian_avulavirus_1_isolate_chicken-Indonesia-I...
# 62     Bat_coronavirus_BtCoV-133-2005_complete_genome
# 63  Tylonycteris_pachypus_bat_coronavirus_HKU4-rel...
# 64                BtPa-BetaCoV_GD2013_complete_genome
# 65  Pipistrellus_abramus_bat_coronavirus_HKU5-rela...
# 66  Homo_sapiens_lncAB371_6_lncRNA_gene_complete_s...
# 67  Homo_sapiens_lncAB370_3_lncRNA_gene_complete_s...
# 68       Homo_sapiens_clone_BAC_JH12_genomic_sequence
# 69  Homo_sapiens_lncAB599_3_lncRNA_gene_complete_s...
# 70  Rattus_norvegicus_4_BAC_CH230-209E1_Childrens_...
# 71  Pig_DNA_sequence_from_clone_CH242-68L20_on_chr...
# 72  Mus_musculus_targeted_non-conditional_lacZ-tag...
# 73  Mus_musculus_BAC_clone_RP23-168H19_from_10_com...
# 74                     J01749_1_cloning_vector_pBR322
# 75                KY926444_1_cloning_vector_pET-hsp12
# 76                 MK787297_1_cloning_vector_pR6K-KCA
# 77       MK908408_1_cloning_vector_pUC_3GLA_U6_1_Bbsl
# 78        MN996867_1_cloning_vector_pcDNA3_1_complete
# 79                   U13856_1_pGEX-5X1_cloning_vector
# 80                     X65300_1_cloning_vector_pGEM_1
# 81                          NC_000001_11_RPS6KA1_gene
# 82                            NC_000004_12_ABCG2_gene
# 83                             NC_000004_12_FGF2_gene
# 84                             NC_000005_10_TERT_gene
# 85                            NC_000006_12_VEGFA_gene
# 86                             NC_000007_14_CAV1_gene
# 87                             NC_000007_14_CFTR_gene
# 88                            NC_000007_14_KCNH2_gene
# 89                            NC_000017_11_BIRC5_gene
# 90                             NC_000017_11_TP53_gene
# 91                              NC_000019_10_BAX_gene
# 92                              NC_000021_9_SOD1_gene
# 93                             NC_000068_8_Cebpb_gene
# 94                              NC_000069_7_Adar_gene
# 95                               NC_000074_7_Mt1_gene
# 96                             NC_000076_7_Ascl1_gene
#
#                     Accession  \
# 0                  AF274751_1
# 1                  AJ289709_1
# 2                  DQ011855_1
# 3                  DQ022305_2
# 4                  DQ079883_1
# 5                  DQ079895_1
# 6                  DQ084199_1
# 7                  DQ084200_1
# 8                  EU410304_1
# 9                  FJ217162_1
# 10                 JF714652_1
# 11                 KC881006_1
# 12                 KF367457_1
# 13                 KF686346_1
# 14                 KJ997912_1
# 15                 KX868289_2
# 16                   L22089_1
# 17                   M19183_1
# 18                 MG772933_1
# 19                 MK625641_1
# 20                 MK651076_1
# 21                 MK920923_1
# 22                 MN996532_1
# 23                 MN996867_1
# 24                NC_001362_1
# 25                NC_001437_1
# 26                NC_001451_1
# 27                NC_001460_1
# 28                NC_001474_2
# 29                NC_001477_1
# 30                NC_001502_1
# 31                NC_001549_1
# 32                NC_001608_3
# 33                NC_001659_2
# 34                NC_001669_1
# 35                NC_001906_3
# 36                NC_001921_1
# 37                NC_002306_3
# 38                NC_002645_1
# 39                NC_002728_1
# 40                NC_003436_1
# 41                NC_003663_2
# 42                NC_004003_1
# 43                NC_004102_1
# 44                NC_004162_2
# 45                NC_004718_3
# 46                NC_005300_2
# 47                NC_005301_3
# 48                NC_005302_1
# 49                NC_006213_1
# 50                NC_006273_2
# 51                NC_006549_1
# 52                NC_009019_1
# 53                NC_009020_1
# 54                NC_012532_1
# 55                NC_019843_3
# 56                NC_032993_1
# 57                NC_038236_1
# 58                NC_044948_1
# 59                NC_045512_2
# 60                NC_048217_1
# 61                 MN727300_2
# 62                 DQ648794_1
# 63                 MN611519_1
# 64                 KJ473820_1
# 65                 MN611520_1
# 66                 MK280367_1
# 67                 MK280359_1
# 68                 MF164268_1
# 69                 MK279923_1
# 70                 AC105600_5
# 71                 FP326762_5
# 72                 JN950623_1
# 73                 AC123074_2
# 74                   J01749_1
# 75                 KY926444_1
# 76                 MK787297_1
# 77                 MK908408_1
# 78                 MN996867_1
# 79                   U13856_1
# 80                   X65300_1
# 81  NC_000001_11_RPS6KA1_gene
# 82    NC_000004_12_ABCG2_gene
# 83     NC_000004_12_FGF2_gene
# 84     NC_000005_10_TERT_gene
# 85    NC_000006_12_VEGFA_gene
# 86     NC_000007_14_CAV1_gene
# 87     NC_000007_14_CFTR_gene
# 88    NC_000007_14_KCNH2_gene
# 89    NC_000017_11_BIRC5_gene
# 90     NC_000017_11_TP53_gene
# 91      NC_000019_10_BAX_gene
# 92      NC_000021_9_SOD1_gene
# 93     NC_000068_8_Cebpb_gene
# 94      NC_000069_7_Adar_gene
# 95       NC_000074_7_Mt1_gene
# 96     NC_000076_7_Ascl1_gene
#
#                                             File_Name  \
# 0     AF274751_1_Bacteriophage_S13_complete_genome.fa
# 1   AJ289709_1_Human_endogenous_retrovirus_H_HERV-...
# 2   DQ011855_1_Porcine_hemagglutinating_encephalom...
# 3   DQ022305_2_Bat_SARS_coronavirus HKU3-1_complet...
# 4        DQ079883_1_Coliphage_ID45_complete_genome.fa
# 5        DQ079895_1_Coliphage_WA11_complete_genome.fa
# 6   DQ084199_1_bat_SARS_coronavirus_HKU3-2_complet...
# 7   DQ084200_1_bat_SARS_coronavirus_HKU3-3_complet...
# 8   EU410304_1_Synthetic_Vaccinia_virus_clone_GLV-...
# 9   FJ217162_1_Cote_d-Ivoire_ebolavirus_complete_g...
# 10  JF714652_1_XMRV-like_mouse_endogenous_retrovir...
# 11  KC881006_1_Bat_SARS-like_coronavirus_Rs3367_co...
# 12  KF367457_1_Bat_SARS-like_coronavirus_WIV1_comp...
# 13  KF686346_1_Human_coronavirus_HKU1_strain_HKU1-...
# 14  KJ997912_1_Enterobacteria_phage_MED1_complete_...
# 15  KX868289_2_Human_adenovirus_12_isolate_GyK010_...
# 16  L22089_1_Mengo_virus_isolate_M_complete_genome.fa
# 17  M19183_1_Woodchuck_hepatitis_virus_WHV_complet...
# 18  MG772933_1_Bat_SARS-like_coronavirus_isolate_b...
# 19  MK625641_1_Porcine_deltacoronavirus_isolate_CH...
# 20  MK651076_1_Swine_acute_diarrhea_syndrome_coron...
# 21  MK920923_1_Rabies_lyssavirus_isolate_19RS359_c...
# 22               MN996532_1_RaTG13_complete_genome.fa
# 23  MN996867_1_Cloning_vector_pcDNA3_1_complete_se...
# 24  NC_001362_1_Friend_murine_leukemia_virus_FB29_...
# 25  NC_001437_1_Japanese_encephalitis_virus_genome.fa
# 26  NC_001451_1_Avian_infectious_bronchitis_virus_...
# 27  NC_001460_1_Human_adenovirus_A_complete_genome.fa
# 28      NC_001474_2_Dengue_virus_2_complete_genome.fa
# 29      NC_001477_1_Dengue_virus_1_complete_genome.fa
# 30  NC_001502_1_Moloney_murine_sarcoma_virus_compl...
# 31  NC_001549_1_Simian_immunodeficiency_virus_comp...
# 32  NC_001608_3_Marburg_marburgvirus_isolate_Marbu...
# 33  NC_001659_2_African_swine_fever_virus_strain_B...
# 34     NC_001669_1_Simian_virus_40_complete_genome.fa
# 35        NC_001906_3_Hendra_virus_complete_genome.fa
# 36  NC_001921_1_canine_distemper_virus_complete_ge...
# 37  NC_002306_3_Feline_infectious_peritonitis_viru...
# 38  NC_002645_1_Human_coronavirus_229E_complete_ge...
# 39         NC_002728_1_Nipah_virus_complete_genome.fa
# 40  NC_003436_1_Porcine_epidemic_diarrhea_virus_co...
# 41        NC_003663_2_Cowpox_virus_complete_genome.fa
# 42  NC_004003_1_Goatpox_virus_Pellor_complete_geno...
# 43  NC_004102_1_Hepatitis_C_virus_genotype_1_compl...
# 44   NC_004162_2_Chikungunya_virus_complete_genome.fa
# 45  NC_004718_3_SARS_coronavirus_Tor2_complete_gen...
# 46  NC_005300_2_Crimean-Congo_hemorrhagic_fever_vi...
# 47  NC_005301_3_Crimean-Congo_hemorrhagic_fever_vi...
# 48  NC_005302_1_Crimean-Congo_hemorrhagic_fever_vi...
# 49  NC_006213_1_Human_coronavirus_OC43_strain_ATCC...
# 50  NC_006273_2_Human_herpesvirus_5_strain_Merlin_...
# 51  NC_006549_1_Singapore_grouper_iridovirus_compl...
# 52                NC_009019_1_HKU4_complete_genome.fa
# 53                NC_009020_1_HKU5_complete_genome.fa
# 54          NC_012532_1_Zika_virus_complete_genome.fa
# 55  NC_019843_3_Middle_East_respiratory_syndrome-r...
# 56  NC_032993_1_Hubei_picorna-like_virus_45_strain...
# 57  NC_038236_1_Vesicular_stomatitis_Indiana_virus...
# 58  NC_044948_1_UNVERIFIED_African_swine_fever_vir...
# 59  NC_045512_2_SARS_CoV_2_Wuahn-Hu-1_complete_gen...
# 60  NC_048217_1_Murine_hepatitis_virus_strain_A59_...
# 61  MN727300_2_Avian_avulavirus_1_isolate_chicken-...
# 62  DQ648794_1_Bat_coronavirus_BtCoV-133-2005_comp...
# 63  MN611519_1_Tylonycteris_pachypus_bat_coronavir...
# 64  KJ473820_1_BtPa-BetaCoV_GD2013_complete_genome.fa
# 65  MN611520_1_Pipistrellus_abramus_bat_coronaviru...
# 66  MK280367_1_Homo_sapiens_lncAB371_6_lncRNA_gene...
# 67  MK280359_1_Homo_sapiens_lncAB370_3_lncRNA_gene...
# 68  MF164268_1_Homo_sapiens_clone_BAC_JH12_genomic...
# 69  MK279923_1_Homo_sapiens_lncAB599_3_lncRNA_gene...
# 70  AC105600_5_Rattus_norvegicus_4_BAC_CH230-209E1...
# 71  FP326762_5_Pig_DNA_sequence_from_clone_CH242-6...
# 72  JN950623_1_Mus_musculus_targeted_non-condition...
# 73  AC123074_2_Mus_musculus_BAC_clone_RP23-168H19_...
# 74                  J01749_1_cloning_vector_pBR322.fa
# 75             KY926444_1_cloning_vector_pET-hsp12.fa
# 76              MK787297_1_cloning_vector_pR6K-KCA.fa
# 77    MK908408_1_cloning_vector_pUC_3GLA_U6_1_Bbsl.fa
# 78     MN996867_1_cloning_vector_pcDNA3_1_complete.fa
# 79                U13856_1_pGEX-5X1_cloning_vector.fa
# 80                  X65300_1_cloning_vector_pGEM_1.fa
# 81                       NC_000001_11_RPS6KA1_gene.fa
# 82                         NC_000004_12_ABCG2_gene.fa
# 83                          NC_000004_12_FGF2_gene.fa
# 84                          NC_000005_10_TERT_gene.fa
# 85                         NC_000006_12_VEGFA_gene.fa
# 86                          NC_000007_14_CAV1_gene.fa
# 87                          NC_000007_14_CFTR_gene.fa
# 88                         NC_000007_14_KCNH2_gene.fa
# 89                         NC_000017_11_BIRC5_gene.fa
# 90                          NC_000017_11_TP53_gene.fa
# 91                           NC_000019_10_BAX_gene.fa
# 92                           NC_000021_9_SOD1_gene.fa
# 93                          NC_000068_8_Cebpb_gene.fa
# 94                           NC_000069_7_Adar_gene.fa
# 95                            NC_000074_7_Mt1_gene.fa
# 96                          NC_000076_7_Ascl1_gene.fa
#
#                       category
# 0                 BSL_organism
# 1                 BSL_organism
# 2                 BSL_organism
# 3                 BSL_organism
# 4                 BSL_organism
# 5                 BSL_organism
# 6                 BSL_organism
# 7                 BSL_organism
# 8                 BSL_organism
# 9                 BSL_organism
# 10                BSL_organism
# 11                BSL_organism
# 12                BSL_organism
# 13                BSL_organism
# 14                BSL_organism
# 15                BSL_organism
# 16                BSL_organism
# 17                BSL_organism
# 18                BSL_organism
# 19                BSL_organism
# 20                BSL_organism
# 21                BSL_organism
# 22                BSL_organism
# 23                BSL_organism
# 24                BSL_organism
# 25                BSL_organism
# 26                BSL_organism
# 27                BSL_organism
# 28                BSL_organism
# 29                BSL_organism
# 30                BSL_organism
# 31                BSL_organism
# 32                BSL_organism
# 33                BSL_organism
# 34                BSL_organism
# 35                BSL_organism
# 36                BSL_organism
# 37                BSL_organism
# 38                BSL_organism
# 39                BSL_organism
# 40                BSL_organism
# 41                BSL_organism
# 42                BSL_organism
# 43                BSL_organism
# 44                BSL_organism
# 45                BSL_organism
# 46                BSL_organism
# 47                BSL_organism
# 48                BSL_organism
# 49                BSL_organism
# 50                BSL_organism
# 51                BSL_organism
# 52                BSL_organism
# 53                BSL_organism
# 54                BSL_organism
# 55                BSL_organism
# 56                BSL_organism
# 57                BSL_organism
# 58                BSL_organism
# 59                BSL_organism
# 60                BSL_organism
# 61                BSL_organism
# 62                     bat_cov
# 63                     bat_cov
# 64                     bat_cov
# 65                     bat_cov
# 66              mamalian_genes
# 67              mamalian_genes
# 68              mamalian_genes
# 69              mamalian_genes
# 70              mamalian_genes
# 71              mamalian_genes
# 72              mamalian_genes
# 73              mamalian_genes
# 74              cloning_vector
# 75              cloning_vector
# 76              cloning_vector
# 77              cloning_vector
# 78              cloning_vector
# 79              cloning_vector
# 80              cloning_vector
# 81  mamalian_expression_vector
# 82  mamalian_expression_vector
# 83  mamalian_expression_vector
# 84  mamalian_expression_vector
# 85  mamalian_expression_vector
# 86  mamalian_expression_vector
# 87  mamalian_expression_vector
# 88  mamalian_expression_vector
# 89  mamalian_expression_vector
# 90  mamalian_expression_vector
# 91  mamalian_expression_vector
# 92  mamalian_expression_vector
# 93  mamalian_expression_vector
# 94  mamalian_expression_vector
# 95  mamalian_expression_vector
# 96  mamalian_expression_vector

# %% [markdown]
# ## Bat Spikes

# %%
bat_result_list=main_worflow(ORGANISM_CSVS[1],CSV_PATHS[1], search_name='batcov', rebuild_db=False)
# Out:
# Running blast2 on SRR5885860
# Elapsed: 43.773359298706055

# %%
bat_result_list
# Out:
# [{'SRR5885860': []}]

# %% [markdown]
# ### Bat spikes and misc other virueses searching for in second run

# %%
df_bat=pd.read_csv(ORGANISM_CSVS[1])
df_bat
# Out:
#                                                  Name  \
# 0                    AAP13441_1_SARS-CoV_Urbani_apike
# 1   AB981587_1_Influenza_virus_type_A_A-NWS-33_H1N...
# 2                       AcCoV-JC34_spike_YP_009380521
# 3                                    BM48-31_BGR_2008
# 4                                 BtRl-BetaCoV_SC2018
# 5                                BtRs-BetaCoV_HuB2013
# 6                                   civet014_AAU04661
# 7                                            CoV_ZC45
# 8                                           CoV_ZXC21
# 9                                          CoV_ZXC21_
# 10                                      GD03_AAS10463
# 11                                    HKU3-1_AAY88866
# 12              HKU3_Spike_mouse_adapted_RBD_QND76034
# 13  HQ008256_1_Influenza_virus_type_A_A-NWS-33_H1N...
# 14  HQ008527_1_Influenza_virus_type_A_A-NWS-33_H1N...
# 15                    Longquan-140_spike_P_AID16716-1
# 16  M91479_1_Influenza_virus_type_A_A-NWS-33_H1N1_...
# 17                                MERS_Spike_QBM11748
# 18  NC_002645_1_Human_coronavirus_229E_complete_ge...
# 19                   OC43_spike_glycoprotein_P36334_1
# 20                             PC4-115_AAV49719_spike
# 21                      RaT13_spike-closed_pdb_6ZGF_C
# 22                             RaT13_spike_QHR63300_2
# 23                                             RaTG13
# 24                         RaTG13_MN996532_2_complete
# 25                          Rf4092_spike_P_ATO98145-1
# 26                     RmYN02_QPD89843_partial_splike
# 27                                       RP3_AAZ67052
# 28                                 RP3_AAZ67052_spike
# 29                          Rs3367_spike_P_AGZ48818-1
# 30                          Rs4081_spike_P_ATO98120-1
# 31                          Rs4084_spike_P_ATO98132-1
# 32                          Rs4231_spike_P_ATO98157-1
# 33                          Rs4237_spike_P_ATO98169-1
# 34                          Rs4247_spike_P_ATO98181-1
# 35                          Rs4255_spike_P_ATO98193-1
# 36                          Rs4874_spike_P_ATO98205-1
# 37                          Rs5567_spike_P_AGZ48818-1
# 38                          Rs7327_spike_P_ATO98218-1
# 39                          Rs9401_spike_P_ATO98231-1
# 40                                           RsSHC014
# 41                        RsSHC014_spike_P_AGZ48806-1
# 42                        SARS-CoV-2_reference_genome
# 43  SARS-CoV-2_spike_glycoprotein_reference_YP_009...
# 44           SARS-CoV-2_spike_glycoptorein_QHD43416_1
# 45                          SARS-CoV-2_Spike_QOH25833
# 46                    SARS-CoV-2_spike_Uniprot_P0DTC2
# 47                           SARS_GZ02_Spike_AAS00003
# 48                  SARS_HTVR_Spike_Follis_et_al_2006
# 49                  SARS_SLLR_Spike_Follis_et_al_2006
# 50                                   SZ3_P59594_spike
# 51  U08903_1_Influenza_virus_type_A_A-NWS-33_H1N1_...
# 52  U08904_1_Influenza_virus_type_A_A-NWS-33_H1N1_...
# 53                              Urbani_AYV99817_spike
# 54                           WIV16_spike_P_ALK02457-1
# 55                            WIV1_spike_P_AGZ48828-1
# 56                                ZC45_Spike_AVP78031
# 57                               ZXC21_Spike_AVP78042
#
#                                             Accession  \
# 0                    AAP13441_1_SARS-CoV_Urbani_apike
# 1   AB981587_1_Influenza_virus_type_A_A-NWS-33_H1N...
# 2                       AcCoV-JC34_spike_YP_009380521
# 3                                    BM48-31_BGR_2008
# 4                                 BtRl-BetaCoV_SC2018
# 5                                BtRs-BetaCoV_HuB2013
# 6                                   civet014_AAU04661
# 7                                            CoV_ZC45
# 8                                           CoV_ZXC21
# 9                                          CoV_ZXC21_
# 10                                      GD03_AAS10463
# 11                                    HKU3-1_AAY88866
# 12              HKU3_Spike_mouse_adapted_RBD_QND76034
# 13  HQ008256_1_Influenza_virus_type_A_A-NWS-33_H1N...
# 14  HQ008527_1_Influenza_virus_type_A_A-NWS-33_H1N...
# 15                    Longquan-140_spike_P_AID16716-1
# 16  M91479_1_Influenza_virus_type_A_A-NWS-33_H1N1_...
# 17                                MERS_Spike_QBM11748
# 18  NC_002645_1_Human_coronavirus_229E_complete_ge...
# 19                   OC43_spike_glycoprotein_P36334_1
# 20                             PC4-115_AAV49719_spike
# 21                      RaT13_spike-closed_pdb_6ZGF_C
# 22                             RaT13_spike_QHR63300_2
# 23                                             RaTG13
# 24                         RaTG13_MN996532_2_complete
# 25                          Rf4092_spike_P_ATO98145-1
# 26                     RmYN02_QPD89843_partial_splike
# 27                                       RP3_AAZ67052
# 28                                 RP3_AAZ67052_spike
# 29                          Rs3367_spike_P_AGZ48818-1
# 30                          Rs4081_spike_P_ATO98120-1
# 31                          Rs4084_spike_P_ATO98132-1
# 32                          Rs4231_spike_P_ATO98157-1
# 33                          Rs4237_spike_P_ATO98169-1
# 34                          Rs4247_spike_P_ATO98181-1
# 35                          Rs4255_spike_P_ATO98193-1
# 36                          Rs4874_spike_P_ATO98205-1
# 37                          Rs5567_spike_P_AGZ48818-1
# 38                          Rs7327_spike_P_ATO98218-1
# 39                          Rs9401_spike_P_ATO98231-1
# 40                                           RsSHC014
# 41                        RsSHC014_spike_P_AGZ48806-1
# 42                        SARS-CoV-2_reference_genome
# 43  SARS-CoV-2_spike_glycoprotein_reference_YP_009...
# 44           SARS-CoV-2_spike_glycoptorein_QHD43416_1
# 45                          SARS-CoV-2_Spike_QOH25833
# 46                    SARS-CoV-2_spike_Uniprot_P0DTC2
# 47                           SARS_GZ02_Spike_AAS00003
# 48                  SARS_HTVR_Spike_Follis_et_al_2006
# 49                  SARS_SLLR_Spike_Follis_et_al_2006
# 50                                   SZ3_P59594_spike
# 51  U08903_1_Influenza_virus_type_A_A-NWS-33_H1N1_...
# 52  U08904_1_Influenza_virus_type_A_A-NWS-33_H1N1_...
# 53                              Urbani_AYV99817_spike
# 54                           WIV16_spike_P_ALK02457-1
# 55                            WIV1_spike_P_AGZ48828-1
# 56                                ZC45_Spike_AVP78031
# 57                               ZXC21_Spike_AVP78042
#
#                                             File_Name category
# 0                 AAP13441_1_SARS-CoV_Urbani_apike.fa     misc
# 1   AB981587_1_Influenza_virus_type_A_A-NWS-33_H1N...     misc
# 2                    AcCoV-JC34_spike_YP_009380521.fa     misc
# 3                                 BM48-31_BGR_2008.fa     misc
# 4                              BtRl-BetaCoV_SC2018.fa     misc
# 5                             BtRs-BetaCoV_HuB2013.fa     misc
# 6                                civet014_AAU04661.fa     misc
# 7                                         CoV_ZC45.fa     misc
# 8                                        CoV_ZXC21.fa     misc
# 9                                       CoV_ZXC21_.fa     misc
# 10                                   GD03_AAS10463.fa     misc
# 11                                 HKU3-1_AAY88866.fa     misc
# 12           HKU3_Spike_mouse_adapted_RBD_QND76034.fa     misc
# 13  HQ008256_1_Influenza_virus_type_A_A-NWS-33_H1N...     misc
# 14  HQ008527_1_Influenza_virus_type_A_A-NWS-33_H1N...     misc
# 15                 Longquan-140_spike_P_AID16716-1.fa     misc
# 16  M91479_1_Influenza_virus_type_A_A-NWS-33_H1N1_...     misc
# 17                             MERS_Spike_QBM11748.fa     misc
# 18  NC_002645_1_Human_coronavirus_229E_complete_ge...     misc
# 19                OC43_spike_glycoprotein_P36334_1.fa     misc
# 20                          PC4-115_AAV49719_spike.fa     misc
# 21                   RaT13_spike-closed_pdb_6ZGF_C.fa     misc
# 22                          RaT13_spike_QHR63300_2.fa     misc
# 23                                          RaTG13.fa     misc
# 24                      RaTG13_MN996532_2_complete.fa     misc
# 25                       Rf4092_spike_P_ATO98145-1.fa     misc
# 26                  RmYN02_QPD89843_partial_splike.fa     misc
# 27                                    RP3_AAZ67052.fa     misc
# 28                              RP3_AAZ67052_spike.fa     misc
# 29                       Rs3367_spike_P_AGZ48818-1.fa     misc
# 30                       Rs4081_spike_P_ATO98120-1.fa     misc
# 31                       Rs4084_spike_P_ATO98132-1.fa     misc
# 32                       Rs4231_spike_P_ATO98157-1.fa     misc
# 33                       Rs4237_spike_P_ATO98169-1.fa     misc
# 34                       Rs4247_spike_P_ATO98181-1.fa     misc
# 35                       Rs4255_spike_P_ATO98193-1.fa     misc
# 36                       Rs4874_spike_P_ATO98205-1.fa     misc
# 37                       Rs5567_spike_P_AGZ48818-1.fa     misc
# 38                       Rs7327_spike_P_ATO98218-1.fa     misc
# 39                       Rs9401_spike_P_ATO98231-1.fa     misc
# 40                                        RsSHC014.fa     misc
# 41                     RsSHC014_spike_P_AGZ48806-1.fa     misc
# 42                     SARS-CoV-2_reference_genome.fa     misc
# 43  SARS-CoV-2_spike_glycoprotein_reference_YP_009...     misc
# 44        SARS-CoV-2_spike_glycoptorein_QHD43416_1.fa     misc
# 45                       SARS-CoV-2_Spike_QOH25833.fa     misc
# 46                 SARS-CoV-2_spike_Uniprot_P0DTC2.fa     misc
# 47                        SARS_GZ02_Spike_AAS00003.fa     misc
# 48               SARS_HTVR_Spike_Follis_et_al_2006.fa     misc
# 49               SARS_SLLR_Spike_Follis_et_al_2006.fa     misc
# 50                                SZ3_P59594_spike.fa     misc
# 51  U08903_1_Influenza_virus_type_A_A-NWS-33_H1N1_...     misc
# 52  U08904_1_Influenza_virus_type_A_A-NWS-33_H1N1_...     misc
# 53                           Urbani_AYV99817_spike.fa     misc
# 54                        WIV16_spike_P_ALK02457-1.fa     misc
# 55                         WIV1_spike_P_AGZ48828-1.fa     misc
# 56                             ZC45_Spike_AVP78031.fa     misc
# 57                            ZXC21_Spike_AVP78042.fa     misc
